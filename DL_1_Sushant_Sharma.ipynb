# %%
import tensorflow as t
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
x=np.array([1,2,3,4],dtype=float)
y=np.array([2,4,6,8],dtype=float)

# %%
model=tf.keras.Sequential([
    tf.keras.Input(shape=(1,)),
    tf.keras.layers.Dense(1)
])

# %%
model.compile(optimizer='sgd',loss='mean_squared_error')

# %%
model.fit(x,y,epochs=10)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - loss: 41.1626
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 28.5874
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 19.8616
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 13.8068
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 9.6054
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 6.6899
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 4.6668
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 3.2629
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 2.2886
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.6124

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
#Step 1: convert data into numpy arrays
x=np.array([1,2,3,4],dtype=float)
y=np.array([2,4,6,8],dtype=float)

# %%
#step 2: define model
model=Sequential([Dense(1,input_shape=(1,))])

# %%
#compile the model
model.compile(optimizer='sgd',loss='mean_squared_error')

# %%
#train the model
model.fit(x,y,epochs=10)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - loss: 7.4487
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 5.1731
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 3.5941
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 2.4985
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.7382
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 1.2106
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.8445
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.5904
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.4141
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.2918

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np

# %%
model=nn.Linear(1,1)
criterion=nn.MSELoss()
optimizer=optim.SGD(model.parameters(),lr=0.01)
x= torch.tensor([[1.],[2.],[3.],[4.]])
y= torch.tensor([[2.],[4.],[6.],[8.]])

# %%
for epoch in range(10):
    optimizer.zero_grad()
    outputs=model(x)
    loss=criterion(outputs,y)
    loss.backward()
    optimizer.step()
    print(f'Epoch {epoch+1}, Loss: {loss.item()}')
# Out:
# Epoch 1, Loss: 12.032669067382812
# Epoch 2, Loss: 8.355769157409668
# Epoch 3, Loss: 5.804407119750977
# Epoch 4, Loss: 4.034031391143799
# Epoch 5, Loss: 2.805567741394043
# Epoch 6, Loss: 1.953122854232788
# Epoch 7, Loss: 1.3615918159484863
# Epoch 8, Loss: 0.951102614402771
# Epoch 9, Loss: 0.6662352085113525
# Epoch 10, Loss: 0.468533992767334
